# %% [markdown]
# # Land Cover Classification Framework
#
# The workflow will cover how to retrieve LandSat Imagery and create a landcover classifier. We will use the landcover classifier to examine changes over time.
#
# ## Case Application: Great Salt Lake
#
# The Great Salt Lake (GSL) fluctuates both from natural seasonality, year-to-year climate anomolies, and anthropogentic water use (e.g., diversions, growth, development). In today's example, we will retrieve LandSat imagery and develop a land cover classifier to examine the changes in area of the GSL over time.

# %%
from utils import getLandSat, plotting
import ee
import rasterio
import matplotlib.pyplot as plt
# Out:
# /home/whitelightning450/mambaforge/envs/hyriver/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ### LandSat Data Retrievel
#
# Use the data retrievel functions to collect LandSat Imagery of the GSL

# %%
# Define the bounding box for the region of interest (ROI), we can get these coordinates from Google Earth or any GIS software. The coordinates are in the format [xmin, ymin, xmax, ymax].
xmin = -113.2
xmax = -111.95
ymin = 40.5
ymax = 41.85

# # Get the ROI as a GeoJSON object
roi = getLandSat.get_bbox([xmin, ymin, xmax, ymax])

#call the getLandSat function to download the data for the specified ROI and time range
getLandSat.export_monthly_range_parallel( #This function parallelizes the download of Landsat data for a specified region of interest (ROI) and time range, allowing for faster data retrieval.
    roi=roi, #roi: The region of interest defined as a GeoJSON object, specifying the area for which the Landsat data will be downloaded.
    output_dir="data/LandSat/GSL", #output_dir: The directory where the downloaded Landsat data will be saved. In this case, it is set to "data/LandSat/GSL".
    start_year=1985, #start_year: The starting year of the time range for which the Landsat data will be downloaded. In this case, it is set to 1985.
    end_year=2025, #end_year: The ending year of the time range for which the Landsat data will be downloaded. In this case, it is set to 2025.
    max_workers=3, #max_workers: The maximum number of worker threads to use for parallel processing. In this case, it is set to 3, which means that up to 3 threads will be used to download the data concurrently.
    months_before=2, #months_before: The number of months before the specified start year to include in the download. In this case, it is set to 2, which means that data from 2 months before the start year (1985) will also be included in the download.
    months_after=2, #months_after: The number of months after the specified end year to include in the download. In this case, it is set to 2, which means that data from 2 months after the end year (2025) will also be included in the download.
    reducer="median" #reducer: The method used to aggregate the Landsat data when multiple images are available for the same time period. In this case, it is set to "median", which means that the median value of the available images will be used for each pixel in the output data.
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Prepared 492 monthly jobs
# Generating URL ...
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/ef27978442fe6224374353ebabab7531-e19e93507a29dc26952723bea2027440:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/81603fe4e40c43f9a7c35e217afb4e73-c9cacc013b310b1f39d88218c7c7db61:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/8ac8e5dd59a2a8d25231aa93ea360f4d-8cb7a4d662b5606118e8e5071f80622c:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_03.tif
# Saved to data/LandSat/GSL/GSL_1985_03.tif
# Finished: data/LandSat/GSL/GSL_1985_03.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_
getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/2853e9a6d8a53c3106251ba6cdcae067-4a488f13a13363e2e598def993a660a6:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_09.tif
# Saved to data/LandSat/GSL/GSL_1986_09.tif
# Finished: data/LandSat/GSL/GSL_1986_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/3b16862cd6217576c8b420330aed2d82-82dbba72263d008b5ead65a4d9e6b17c:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_10.tif
# Saved to data/LandSat/GSL/GSL_1986_10.tif
# Finished: data/LandSat/GSL/GSL_1986_10.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_11.tif
# Saved to data/LandSat/GSL/GSL_1986_11.tif
# Finished: data/LandSat/GSL/GSL_1986_11.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_12.tif
# Saved to data/LandSat/GSL/GSL_1986_12.tif
# Finished: data/LandSat/GSL/GSL_1986_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f0c223931f9037d3b155f5bfa6ed111d-1d0a489e9c22e4535bbf8bd57a5dfa01:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/6615d513fd2069b7c24bd3b40a8accfa-c9bb80bd32136035547ad582e72449b4:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/51160944ff0879dc80df7403bb035c60-9dc7755ed6693b3b06dce1d1beffca72:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_02.tif
# Saved to data/LandSat/GSL/GSL_1987_02.tif
# Finished: data/LandSat/GSL/GSL_1987_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/da97f61966ae4a9514b608d2262a4ccb-3f333c165594cce6ec07eb61e87cf98a:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_01.tif
# Saved to data/LandSat/GSL/GSL_1987_01.tif
# Finished: data/LandSat/GSL/GSL_1987_01.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_03.tif
# Saved to data/LandSat/GSL/GSL_1987_03.tif
# Finished: data/LandSat/GSL/GSL_1987_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/07066d5bc2eced31e37f3a13d627c5f5-e4b2873bb7281ba10eff51e18eb7a552:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/dd734c7bf70827dc40df52dfe7e7c82a-b050f4f1618a6703db73b6b892d4b83d:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_04.tif
# Saved to data/LandSat/GSL/GSL_1987_04.tif
# Finished: data/LandSat/GSL/GSL_1987_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f6221a3d6acd72316c75cd1a09f5581e-bb389a0e50442a37939299b1bd815800:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_06.tif
# Saved to data/LandSat/GSL/GSL_1987_06.tif
# Finished: data/LandSat/GSL/GSL_1987_06.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_05.tif
# Saved to data/LandSat/GSL/GSL_1987_05.tif
# Finished: data/LandSat/GSL/GSL_1987_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects
atics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_01.tif
# Saved to data/LandSat/GSL/GSL_1989_01.tif
# Finished: data/LandSat/GSL/GSL_1989_01.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/c86689cc2affda58bd1dafe27f1c8af3-377a8765da679595bbd1cfe83c6a9f13:getPixels
# Please wait ...
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_02.tif
# Saved to data/LandSat/GSL/GSL_1989_02.tif
# Finished: data/LandSat/GSL/GSL_1989_02.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/c8d9da1b5dc14fab6374567aed4dde28-72235df0414d0b8e20a64c4961c8f756:getPixels
# Please wait ...
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_03.tif
# Saved to data/LandSat/GSL/GSL_1989_03.tif
# Finished: data/LandSat/GSL/GSL_1989_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/0a8c486c1f54bd8f6312564371d1b9db-4d1641205b20caca75207fb921ccdd61:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_04.tif
# Saved to data/LandSat/GSL/GSL_1989_04.tif
# Finished: data/LandSat/GSL/GSL_1989_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/c5df72231245530f8b5b06cf16eb381a-6710321b6fcf2b293779c7a1eba3b70a:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f277a9878ee2e8379850a428e6fdd3b0-cba45cd358cf20915512e60b8bf03921:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_05.tif
# Saved to data/LandSat/GSL/GSL_1989_05.tif
# Finished: data/LandSat/GSL/GSL_1989_05.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_07.tif
# Saved to data/LandSat/GSL/GSL_1989_07.tif
# Finished: data/LandSat/GSL/GSL_1989_07.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_06.tif
# Saved to data/LandSat/GSL/GSL_1989_06.tif
# Finished: data/LandSat/GSL/GSL_1989_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/2a2ec0f8f7b4b46f6e3627806f964fd5-6440725fe583cd990373045caa2b3d71:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/1d8fefa68059922b0543eaba7d151a0e-d91365b74a843a19bd565bfbc76fbe40:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/aab626bb04b5a83776a5f290d4604d0d-58ba338478a6e78aac32c909be762e4d:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_08.tif
# Saved to data/LandSat/GSL/GSL_1989_08.tif
# Finished: data/LandSat/GSL/GSL_1989_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/3906c412629f7052f23a6ecb2529aac7-483c3dfd59621266c8806f91f20aa21b:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_10.tif
# Saved to data/LandSat/GSL/GSL_1989_10.tif
# Finished: data/LandSat/GSL/GSL_1989_10.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_09.tif
# Saved to data/LandSat/GSL/GSL_1989_09.tif
# Finished: data/LandSat/GSL/GSL_1989_09.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/1d665121b56b0c0cfca83f0ad54dd860-59bde44493a3c113928f60b2227c8c6b:getPixels
# Please wait ...
# No images for 1989-11-01 to 1990-04-01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/d5b1d07e9513ea3cc8e269528d809158-535276a7291d98a4213c6ff16b4f6f7e:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_11.tif
# Saved to data/LandSat/GSL/GSL_1989_11.tif
# Finished: data/LandSat/GSL/GSL_1989_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/7c8fdb8d1056f8d91e3d94b4ee170049-3b9a34b4235ba243b027fa18e5f2f4c6:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_02.tif
# Saved to data/LandSat/GSL/GSL_1990_02.tif
# Finished: data/LandSat/GSL/GSL_1990_02.tif
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_12.tif
# Saved to data/LandSat/GSL/GSL_1989_12.tif
# Finished: data/LandSat/GSL/GSL_1989_12.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/272df565a1de2c5e4fe98e3549bac4c2-16749e545511d0d6829099e39f7cc13c:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/5c5b48ac9678b096ba68810203339b19-83b3b2f2eda3f0b5a64ba533c1d31414:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_03.tif
# Saved to data/LandSat/GSL/GSL_1990_03.tif
# Finished: data/LandSat/GSL/GSL_1990_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/cace9a7767e6a1db09ea5274c39d1468-0b3cfce3d6e0c923c5c28509aa4f7de3:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_04.tif
# Saved to data/LandSat/GSL/GSL_1990_04.tif
# Finished: data/LandSat/GSL/GSL_1990_04.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_05.tif
# Saved to data/LandSat/GSL/GSL_1990_05.tif
# Finished: data/LandSat/GSL/GSL_1990_05.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/1cd17620d88bc3dce08a8bd55cced672-c5e91916d85fa01f732f423a4455e37a:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/24a88216b62ead00a66abd9cb31b1153-671bc8fc0c189360c3ef676e40a72fd3:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_06.tif
# Saved to data/LandSat/GSL/GSL_1990_06.tif
# Finished: data/LandSat/GSL/GSL_1990_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/e3c16cb6cfcdcd213de5fd55c0178d5c-c8c59414d5a0542e5902e45bf27867f1:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_08.tif
# Saved to data/LandSat/GSL/GSL_1990_08.tif
# Finished: data/LandSat/GSL/GSL_1990_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/e5d25460aa1d90db6236ae6f7e11c33c-c8d967db25441fdc5247e1d444f7f5e8:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_07.tif
# Saved to data/LandSat/GSL/GSL_1990_07.tif
# Finished: data/LandSat/GSL/GSL_1990_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/572b000a21ff883622fd30f1cd32a7e2-8f486a2538ea60b467f9a9a0cb3c618c:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_09.tif
# Saved to data/LandSat/GSL/GSL_1990_09.tif
# Finished: data/LandSat/GSL/GSL_1990_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/5a89d7b14d1c71e803366d925b5bc4bf-c0921ff0e4e774c603c3fc12bb21d27a:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_10.tif
# Saved to data/LandSat/GSL/GSL_1990_10.tif
# Finished: data/LandSat/GSL/GSL_1990_10.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_11.tif
# Saved to data/LandSat/GSL/GSL_1990_11.tif
# Finished: data/LandSat/GSL/GSL_1990_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/02ba928031c9163199cfe90b0c1dcff1-734fff807659598c0816daa5568bd03b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/7aaee4daffc62dfbf3577c5df4e65b70-c95ea653293fd33207f73d83d3c7e46d:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_12.tif
# Saved to data/LandSat/GSL/GSL_1990_12.tif
# Finished: data/LandSat/GSL/GSL_1990_12.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_01.tif
# Saved to data/LandSat/GSL/GSL_1991_01.tif
# Finished: data/LandSat/GSL/GSL_1991_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/d82224f9a5434a343410a70f9e704881-5fe19924887e5a39e0b2a0b6686b9ac3:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_02.zip'
# Saved to data/LandSat/GSL/GSL_1991_02.tif
# Finished: data/LandSat/GSL/GSL_1991_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/dc36c9ce249b2b04f9543201b2c8b850-e4fd865df33726045c0ed601d283bada:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f6280d0f4cc8129ee0790753a4e8c5b3-8e9334618af3e8a935c2d027caece4de:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_03.tif
# Saved to data/LandSat/GSL/GSL_1991_03.tif
# Finished: data/LandSat/GSL/GSL_1991_03.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_04.tif
# Saved to data/LandSat/GSL/GSL_1991_04.tif
# Finished: data/LandSat/GSL/GSL_1991_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/3b79bf62ecf87aa221f1be41db119376-858afd9f5b484bce1646849b2e7b086c:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_05.zip'
# Saved to data/LandSat/GSL/GSL_1991_05.tif
# Finished: data/LandSat/GSL/GSL_1991_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/51088c282d5077cf225b9ae5d1a2a872-ed267c7a2a959b6dd0c58e719186db1f:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_06.tif
# Saved to data/LandSat/GSL/GSL_1991_06.tif
# Finished: data/LandSat/GSL/GSL_1991_06.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_07.tif
# Saved to data/LandSat/GSL/GSL_1991_07.tif
# Finished: data/LandSat/GSL/GSL_1991_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/5a99a0da7ccbdf85056cbc555e721aab-8894d91fcf399f2271808c2af15ee0d5:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/5789564f892659c45911e3310e7bd8ba-641b957c634a080fb3633c3442a9d2d2:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/74455b6b4633339108f5accf2ee2c438-d87422b2ffe9dd2c0e8f1deb740bd6bf:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_10.tif
# Saved to data/LandSat/GSL/GSL_1991_10.tif
# Finished: data/LandSat/GSL/GSL_1991_10.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_09.tif
# Saved to data/LandSat/GSL/GSL_1991_09.tif
# Finished: data/LandSat/GSL/GSL_1991_09.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/32e36c98d998cbff32f7f2626db7bec2-e92583f71a2da93a629855ec4ae17bf9:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/3b6a36a1ba2369ff839a2d41a3481db4-6a0f66425356380dc0a539b646b4d58a:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_12.tif
# Saved to data/LandSat/GSL/GSL_1991_12.tif
# Finished: data/LandSat/GSL/GSL_1991_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/a055fd8f39fe57e234f8051fdeddaa59-cd6b2920bea1962b76e19f3819cc1b35:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_11.tif
# Saved to data/LandSat/GSL/GSL_1991_11.tif
# Finished: data/LandSat/GSL/GSL_1991_11.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_08.tif
# Saved to data/LandSat/GSL/GSL_1991_08.tif
# Finished: data/LandSat/GSL/GSL_1991_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/6b1058f53a174c9d73fac737515c6b71-35431a07c1490531c91324faba13699f:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1992_01.tif
# Saved to data/LandSat/GSL/GSL_1992_01.tif
# Finished: data/LandSat/GSL/GSL_1992_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/9367049171877f3b634fe3a1c8ce046c-97edc132358c3abfa845016a407b3281:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/13a89b3e2612605892ca0532ecba0c78-7ffca966b78c2d944f54b74745bf78d0:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1992_03.tif
# Saved to data/LandSat/GSL/GSL_1992_03.tif
# Finished: data/LandSat/GSL/GSL_1992_03.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1992_04.tif
# Saved to data/LandSat/GSL/GSL_1992_04.tif
# Finished: data/LandSat/GSL/GSL_1992_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/5cb9460e70b13772fa517a3f1848b6f8-9f21173c7bc162f3d6b3d05cbfec8b28:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects
getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/c727418f5cf4f83321ad88ee9d800087-45ba91f3cf898c4609f4b5acd43e0f35:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_09.zip'
# Saved to data/LandSat/GSL/GSL_2022_09.tif
# Finished: data/LandSat/GSL/GSL_2022_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/8fb766ab6137ea5c1f5d58c95da417d5-d7276c96425fcbb4309c1ec8b8cf856b:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_10.tif
# Saved to data/LandSat/GSL/GSL_2022_10.tif
# Finished: data/LandSat/GSL/GSL_2022_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/27bf859857b1406050d0678801bde163-82447cb2823c895bddc41e8e8fe93f5f:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_11.zip'
# Saved to data/LandSat/GSL/GSL_2022_11.tif
# Finished: data/LandSat/GSL/GSL_2022_11.tif
# Generating URL ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_12.zip'
# Saved to data/LandSat/GSL/GSL_2022_12.tif
# Finished: data/LandSat/GSL/GSL_2022_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/dab8c01be3eaf6f05d238cf3b8ef2fed-e1bb7044a187008bbf596ffde502c138:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2023_01.tif'
# Saved to data/LandSat/GSL/GSL_2023_01.tif
# Finished: data/LandSat/GSL/GSL_2023_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/c9ec01aa7e361de3a1be0b33dba7718f-07797c3373de5b38ad39e7defa16e2b7:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/290af521fb452ef383c8731a87579b5c-c5b55f67b5071f1a0305d2c51591fb5e:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_02.tif
# Saved to data/LandSat/GSL/GSL_2023_02.tif
# Finished: data/LandSat/GSL/GSL_2023_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/85a27d8facd2fd4a22f0aaa7228fda25-734d68dba81160f6d232c84ff16923f3:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_03.tif
# Saved to data/LandSat/GSL/GSL_2023_03.tif
# Finished: data/LandSat/GSL/GSL_2023_03.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_04.tif
# Saved to data/LandSat/GSL/GSL_2023_04.tif
# Finished: data/LandSat/GSL/GSL_2023_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/573a99abca49f9ac137676b2f0919f6f-78a0f4fdcecf949a25af557e4c5c8a45:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/079ee47216c6bb3192971b7b13699ade-a21a6ebf74dc3451b8fd3de3609587a8:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2023_05.tif'
# Saved to data/LandSat/GSL/GSL_2023_05.tif
# Finished: data/LandSat/GSL/GSL_2023_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/a1b5ce3d497edfe512fc0e3078b942b4-2ff96ed259b3b3f91483be02178bd5e4:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_06.tif
# Saved to data/LandSat/GSL/GSL_2023_06.tif
# Finished: data/LandSat/GSL/GSL_2023_06.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_07.tif
# Saved to data/LandSat/GSL/GSL_2023_07.tif
# Finished: data/LandSat/GSL/GSL_2023_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/d7f19ab131fcc443e69f921d3eed0905-3af843743ccce865d20173cf67c6e42b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/8b67442540b0bce4345de4aa3944d5fb-e6b361d8df1f9a199c71b1fd9b8c79eb:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_08.zip'
# Saved to data/LandSat/GSL/GSL_2023_08.tif
# Finished: data/LandSat/GSL/GSL_2023_08.tif
# Generating URL ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_09.zip'
# Saved to data/LandSat/GSL/GSL_2023_09.tif
# Finished: data/LandSat/GSL/GSL_2023_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/ce0625723fd4d920b5df7c3b7fd8a13f-a6c71905d8983bf91d82a361ed53e2bb:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2023_10.tif'
# Saved to data/LandSat/GSL/GSL_2023_10.tif
# Finished: data/LandSat/GSL/GSL_2023_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/92c6fcd457b9c84d363ea9fda1b8500b-05215e6981ae6ab9940480dd955af08c:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/cf1aa6080a331ee253e269c398f5a88f-89c4213c52e4a0572718ff9e75879fc7:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2023_11.tif'
# Saved to data/LandSat/GSL/GSL_2023_11.tif
# Finished: data/LandSat/GSL/GSL_2023_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/2df6cc8f18b318140d91359af7b84c32-41a44a922b9a3e6f95ce99cbe2322de4:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_01.tif
# Saved to data/LandSat/GSL/GSL_2024_01.tif
# Finished: data/LandSat/GSL/GSL_2024_01.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_12.tif
# Saved to data/LandSat/GSL/GSL_2023_12.tif
# Finished: data/LandSat/GSL/GSL_2023_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f9059039aef594968e4a476779c84f80-e35e86ebe83ff682092ad80b14bd9ad5:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/abb2e7573a7fe4da317391c4484b8e42-a777bc2e64687285f0df5fa4276e6a54:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_02.zip'
# Saved to data/LandSat/GSL/GSL_2024_02.tif
# Finished: data/LandSat/GSL/GSL_2024_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/02bec702919ee0262815cad29f9cfbf7-67357f26913312153bd6de90d3504c53:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_03.tif
# Saved to data/LandSat/GSL/GSL_2024_03.tif
# Finished: data/LandSat/GSL/GSL_2024_03.tif
# Generating URL ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_04.zip'
# Saved to data/LandSat/GSL/GSL_2024_04.tif
# Finished: data/LandSat/GSL/GSL_2024_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/2d04602234410d10ba12d2a4514fb438-fb957d4afb3fed9a6b84476c105e9cc0:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_05.zip'
# Saved to data/LandSat/GSL/GSL_2024_05.tif
# Finished: data/LandSat/GSL/GSL_2024_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/d1ccb6c01af829bea4fd53810d6219ed-c267d1ce4e2c32b83d7d45d693eb828a:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/055a0df51b852f6353afcb0b070f074a-a38ed5e9668e55b1b637f2dfb7dd0ceb:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_06.tif
# Saved to data/LandSat/GSL/GSL_2024_06.tif
# Finished: data/LandSat/GSL/GSL_2024_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/0ae5bfa8ef1f494ebe0dec59354706a4-42046a9d32bf814b1af0a5809e79b49a:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_07.tif
# Saved to data/LandSat/GSL/GSL_2024_07.tif
# Finished: data/LandSat/GSL/GSL_2024_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/a400932cf9321d333cfa586b06c2ffb1-c53e758f24e8732e69442e4044621505:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2024_08.tif'
# Saved to data/LandSat/GSL/GSL_2024_08.tif
# Finished: data/LandSat/GSL/GSL_2024_08.tif
# Generating URL ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_09.tif
# Saved to data/LandSat/GSL/GSL_2024_09.tif
# Finished: data/LandSat/GSL/GSL_2024_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/34febcfafad1b9a9a53d3bcd7d523c08-91787045a8e0b321c0f865f3aca0d36e:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/3c70688598ad9891f061c87c5782d84c-8560f18e570db6bd564cbbc12761a160:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_10.zip'
# Saved to data/LandSat/GSL/GSL_2024_10.tif
# Finished: data/LandSat/GSL/GSL_2024_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f82b7c1e1e85e4f2a85ce289d0b265a1-72fd6e7dd16172fb5c85f51a45ddf4f9:getPixels
# Please wait ...
# Bad CRC-32 for file 'GSL_2024_11.tif'
# Saved to data/LandSat/GSL/GSL_2024_11.tif
# Finished: data/LandSat/GSL/GSL_2024_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/f3ee44c98fbf05180217703aaf959503-99f79d70be0d201c3fc513349b55092f:getPixels
# Please wait ...
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_01.tif
# Saved to data/LandSat/GSL/GSL_2025_01.tif
# Finished: data/LandSat/GSL/GSL_2025_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/470806009090/thumbnails/1b14d89a75640c0b9e6c10bf98bddacc-850a49a5cbb3a81287bf1b4b1de0b1c0:getPixels
# Please wait ...
# [Errno 2] No such file or directory: '/home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL
atics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_11.zip'
# Saved to data/LandSat/GSL/GSL_2025_11.tif
# Finished: data/LandSat/GSL/GSL_2025_11.tif
# Data downloaded to /home/whitelightning450/HydroInformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_12.tif
# Saved to data/LandSat/GSL/GSL_2025_12.tif
# Finished: data/LandSat/GSL/GSL_2025_12.tif
# All monthly exports completed.

# %% [markdown]
# ## Plot some images
#
# We want to plot some of the images to double check out work.
# * How does the image look?
# * Is the bounding box correct?
# * How is the color scaling?

# %%
Path = 'data/LandSat/GSL/' #The directory where the downloaded Landsat data is saved. In this case, it is set to "data/LandSat/GSL/".
date = '1986_01' #The specific date for which the Landsat image will be plotted. In this case, it is set to '1986_01', which likely corresponds to January 1986.

# This function call for plotting the Landsat image for the specified date using the data stored in the specified directory. The function reads the relevant Landsat data from the directory, processes it, and then generates a visual representation of the image for the given date.
plotting.plot_landsat_image(Path, date)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Exploring changes over time
#
# A key element of the exercise is to quantitatively describe changes in GSL surface area over time. A first step is to qualitaively do this by making a time-series gif of the images and visually assess if we in fact do observed changes.

# %%
import os
import glob
import re
import numpy as np
import rasterio
import imageio.v2 as imageio
from PIL import Image


def natural_sort_key(path):
    """
    Sort filenames like GSL_1985_01.tif, GSL_1985_02.tif, ...
    """
    name = os.path.basename(path)
    parts = re.split(r"(\d+)", name)
    return [int(p) if p.isdigit() else p for p in parts]


def tif_to_rgb_array(tif_path, scale_max=0.3):
    """
    Read a 3-band Landsat GeoTIFF and convert to uint8 RGB.
    Assumes bands are in RGB order or select them before export.
    """
    with rasterio.open(tif_path) as src:
        arr = src.read([1, 2, 3]).astype("float32")  # (3, rows, cols)

    # Convert to (rows, cols, 3)
    arr = np.moveaxis(arr, 0, -1)

    # Clip and scale for display
    arr = np.clip(arr, 0, scale_max)
    arr = arr / scale_max
    arr = (arr * 255).astype(np.uint8)

    return arr


def make_gif_from_tifs(
    input_dir,
    output_gif="data/LandSat/GSL/gsl_timelapse.gif",
    pattern="GSL_*.tif",
    scale_max=0.3,
    frame_duration=0.2,
    max_width=1200
):
    """
    Create a GIF timelapse from monthly Landsat TIFFs.
    """
    tif_files = glob.glob(os.path.join(input_dir, pattern))
    tif_files = sorted(tif_files, key=natural_sort_key)

    if not tif_files:
        raise FileNotFoundError(f"No TIFFs found in {input_dir} matching {pattern}")

    frames = []

    for tif in tif_files:
        print(f"Adding {os.path.basename(tif)}")

        img = tif_to_rgb_array(tif, scale_max=scale_max)

        # Optional resize to keep GIF manageable
        h, w = img.shape[:2]
        if w > max_width:
            new_h = int(h * max_width / w)
            img = np.array(Image.fromarray(img).resize((max_width, new_h)))

        frames.append(img)

    os.makedirs(os.path.dirname(output_gif), exist_ok=True)
    imageio.mimsave(output_gif, frames, duration=frame_duration)

    print(f"Saved GIF to {output_gif}")

# %%
make_gif_from_tifs(
    input_dir="data/LandSat/GSL",
    output_gif="data/LandSat/GSL/gsl_timelapse.gif",
    scale_max=0.3,
    frame_duration=0.25
)
